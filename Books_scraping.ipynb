# %%
import requests
import pandas as pd

# %%
from bs4 import BeautifulSoup

# %%
url = "https://books.toscrape.com/catalogue/page-1.html"

# %%
response = requests.get(url)

# %%
response = response.content

# %%
soup = BeautifulSoup(response, 'html.parser')

# %%
#soup

# %%
ol =soup.find('ol')

# %%
articles = ol.find_all('article', class_='product_pod')

# %%
#articles

# %% [markdown]
# for multiple pages
# simply put a loop on url

# %%
books=[]
for i in range(1,51):
    url = f"https://books.toscrape.com/catalogue/page-{i}.html"
    response = requests.get(url)
    response = response.content
    soup = BeautifulSoup(response, 'html.parser')
    ol =soup.find('ol') 
    articles = ol.find_all('article', class_='product_pod')


    for article in articles:
        image = article.find('img')
        title = image.attrs['alt']
        star = article.find('p')
        star = star['class']
        price = article.find('p', class_='price_color').text
        price = float(price[1:])
        books.append([title, price, star])

# %%
df = pd.DataFrame(books, columns=['Ttile','Price','Star Rating'])

# %%
df.to_csv('books.csv')

# %%
len(books)
# Out:
# 1000

# %%
books
# Out:
# [['A Light in the Attic', 51.77, ['star-rating', 'Three']],
#  ['Tipping the Velvet', 53.74, ['star-rating', 'One']],
#  ['Soumission', 50.1, ['star-rating', 'One']],
#  ['Sharp Objects', 47.82, ['star-rating', 'Four']],
#  ['Sapiens: A Brief History of Humankind', 54.23, ['star-rating', 'Five']],
#  ['The Requiem Red', 22.65, ['star-rating', 'One']],
#  ['The Dirty Little Secrets of Getting Your Dream Job',
#   33.34,
#   ['star-rating', 'Four']],
#  ['The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#   17.93,
#   ['star-rating', 'Three']],
#  ['The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#   22.6,
#   ['star-rating', 'Four']],
#  ['The Black Maria', 52.15, ['star-rating', 'One']],
#  ['Starving Hearts (Triangular Trade Trilogy, #1)',
#   13.99,
#   ['star-rating', 'Two']],
#  ["Shakespeare's Sonnets", 20.66, ['star-rating', 'Four']],
#  ['Set Me Free', 17.46, ['star-rating', 'Five']],
#  ["Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)",
#   52.29,
#   ['star-rating', 'Five']],
#  ['Rip it Up and Start Again', 35.02, ['star-rating', 'Five']],
#  ['Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',
#   57.25,
#   ['star-rating', 'Three']],
#  ['Olio', 23.88, ['star-rating', 'One']],
#  ['Mesaerion: The Best Science Fiction Stories 1800-1849',
#   37.59,
#   ['star-rating', 'One']],
#  ['Libertarianism for Beginners', 51.33, ['star-rating', 'Two']],
#  ["It's Only the Himalayas", 45.17, ['star-rating', 'Two']],
#  ['In Her Wake', 12.84, ['star-rating', 'One']],
#  ['How Music Works', 37.32, ['star-rating', 'Two']],
#  ['Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More',
#   30.52,
#   ['star-rating', 'Three']],
#  ['Chase Me (Paris Nights #2)', 25.27, ['star-rating', 'Five']],
#  ['Black Dust', 34.53, ['star-rating', 'Five']],
#  ['Birdsong: A Story in Pictures', 54.64, ['star-rating', 'Three']],
#  ["America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana",
#   22.5,
#   ['star-rating', 'Three']],
#  ['Aladdin and His Wonderful Lamp', 53.13, ['star-rating', 'Three']],
#  ['Worlds Elsewhere: Journeys Around Shakespeare’s Globe',
#   40.3,
#   ['star-rating', 'Five']],
#  ['Wall and Piece', 44.18, ['star-rating', 'Four']],
#  ['The Four Agreements: A Practical Guide to Personal Freedom',
#   17.66,
#   ['star-rating', 'Five']],
#  ['The Five Love Languages: How to Express Heartfelt Commitment to Your Mate',
#   31.05,
#   ['star-rating', 'Three']],
#  ['The Elephant Tree', 23.82, ['star-rating', 'Five']],
#  ['The Bear and the Piano', 36.89, ['star-rating', 'One']],
#  ["Sophie's World", 15.94, ['star-rating', 'Five']],
#  ['Penny Maybe', 33.29, ['star-rating', 'Three']],
#  ['Maude (1883-1993):She Grew Up with the country',
#   18.02,
#   ['star-rating', 'Two']],
#  ['In a Dark, Dark Wood', 19.63, ['star-rating', 'One']],
#  ['Behind Closed Doors', 52.22, ['star-rating', 'Four']],
#  ["You can't bury them all: Poems", 33.63, ['star-rating', 'Two']],
#  ['Slow States of Collapse: Poems', 57.31, ['star-rating', 'Three']],
#  ['Reasons to Stay Alive', 26.41, ['star-rating', 'Two']],
#  ['Private Paris (Private #10)', 47.61, ['star-rating', 'Five']],
#  ['#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.',
#   23.11,
#   ['star-rating', 'Five']],
#  ['Without Borders (Wanderlove #1)', 45.07, ['star-rating', 'Two']],
#  ['When We Collided', 31.77, ['star-rating', 'One']],
#  ['We Love You, Charlie Freeman', 50.27, ['star-rating', 'Five']],
#  ['Untitled Collection: Sabbath Poems 2014', 14.27, ['star-rating', 'Four']],
#  ['Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness',
#   44.18,
#   ['star-rating', 'Four']],
#  ['Unicorn Tracks', 18.78, ['star-rating', 'Three']],
#  ['Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink',
#   25.52,
#   ['star-rating', 'One']],
#  ['Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)',
#   16.28,
#   ['star-rating', 'One']],
#  ['Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity',
#   31.12,
#   ['star-rating', 'Three']],
#  ['This One Summer', 19.49, ['star-rating', 'Four']],
#  ['Thirst', 17.27, ['star-rating', 'Five']],
#  ['The Torch Is Passed: A Harding Family Story',
#   19.09,
#   ['star-rating', 'One']],
#  ['The Secret of Dreadwillow Carse', 56.13, ['star-rating', 'One']],
#  ['The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!',
#   56.41,
#   ['star-rating', 'One']],
#  ['The Past Never Ends', 56.5, ['star-rating', 'Four']],
#  ['The Natural History of Us (The Fine Art of Pretending #2)',
#   45.22,
#   ['star-rating', 'Three']],
#  ['The Nameless City (The Nameless City #1)', 38.16, ['star-rating', 'Four']],
#  ['The Murder That Never Was (Forensic Instincts #5)',
#   54.11,
#   ['star-rating', 'Three']],
#  ["The Most Perfect Thing: Inside (and Outside) a Bird's Egg",
#   42.96,
#   ['star-rating', 'Four']],
#  ['The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy',
#   23.89,
#   ['star-rating', 'Four']],
#  ['The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing',
#   16.77,
#   ['star-rating', 'Three']],
#  ['The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer',
#   20.59,
#   ['star-rating', 'Five']],
#  ['The Gutsy Girl: Escapades for Your Life of Epic Adventure',
#   37.13,
#   ['star-rating', 'One']],
#  ['The Electric Pencil: Drawings from Inside State Hospital No. 3',
#   56.06,
#   ['star-rating', 'One']],
#  ['The Death of Humanity: and the Case for Life',
#   58.11,
#   ['star-rating', 'Four']],
#  ['The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life',
#   49.05,
#   ['star-rating', 'Three']],
#  ['The Art Forger', 40.76, ['star-rating', 'Three']],
#  ['The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind',
#   19.73,
#   ['star-rating', 'One']],
#  ["The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution",
#   32.24,
#   ['star-rating', 'Five']],
#  ['Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up',
#   41.83,
#   ['star-rating', 'Four']],
#  ['Soul Reader', 39.58, ['star-rating', 'Two']],
#  ['Security', 39.25, ['star-rating', 'Two']],
#  ['Saga, Volume 6 (Saga (Collected Editions) #6)',
#   25.02,
#   ['star-rating', 'Three']],
#  ['Saga, Volume 5 (Saga (Collected Editions) #5)',
#   51.04,
#   ['star-rating', 'Two']],
#  ['Reskilling America: Learning to Labor in the Twenty-First Century',
#   19.83,
#   ['star-rating', 'Two']],
#  ['Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)',
#   50.4,
#   ['star-rating', 'Three']],
#  ['Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)',
#   13.61,
#   ['star-rating', 'Five']],
#  ['Princess Between Worlds (Wide-Awake Princess #5)',
#   13.34,
#   ['star-rating', 'Five']],
#  ['Pop Gun War, Volume 1: Gift', 18.97, ['star-rating', 'One']],
#  ['Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics',
#   36.28,
#   ['star-rating', 'Two']],
#  ['Patience', 10.16, ['star-rating', 'Three']],
#  ['Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)',
#   15.44,
#   ['star-rating', 'Four']],
#  ['orange: The Complete Collection 1 (orange: The Complete Collection #1)',
#   48.41,
#   ['star-rating', 'One']],
#  ['Online Marketing for Busy Authors: A Step-By-Step Guide',
#   46.35,
#   ['star-rating', 'One']],
#  ['On a Midnight Clear', 14.07, ['star-rating', 'Three']],
#  ['Obsidian (Lux #1)', 14.86, ['star-rating', 'Two']],
#  ['My Paris Kitchen: Recipes and Stories', 33.37, ['star-rating', 'Two']],
#  ['Masks and Shadows', 56.4, ['star-rating', 'Two']],
#  ['Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed',
#   14.02,
#   ['star-rating', 'Four']],
#  ['Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)',
#   46.91,
#   ['star-rating', 'Two']],
#  ['Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)',
#   45.61,
#   ['star-rating', 'Three']],
#  ['Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)',
#   19.92,
#   ['star-rating', 'Two']],
#  ['Layered: Baking, Building, and Styling Spectacular Cakes',
#   40.11,
#   ['star-rating', 'One']],
#  ['Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)',
#   53.9,
#   ['star-rating', 'Two']],
#  ['Join', 35.67, ['star-rating', 'Five']],
#  ['In the Country We Love: My Family Divided', 22.0, ['star-rating', 'Four']],
#  ['Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine',
#   57.36,
#   ['star-rating', 'Five']],
#  ['I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)',
#   29.17,
#   ['star-rating', 'Two']],
#  ['I am a Hero Omnibus Volume 1', 54.63, ['star-rating', 'Three']],
#  ['How to Be Miserable: 40 Strategies You Already Use',
#   46.03,
#   ['star-rating', 'One']],
#  ['Her Backup Boyfriend (The Sorensen Family #1)',
#   33.97,
#   ['star-rating', 'One']],
#  ['Giant Days, Vol. 2 (Giant Days #5-8)', 22.11, ['star-rating', 'Two']],
#  ['Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton',
#   29.69,
#   ['star-rating', 'Three']],
#  ['First and First (Five Boroughs #3)', 15.97, ['star-rating', 'Four']],
#  ['Fifty Shades Darker (Fifty Shades #2)', 21.96, ['star-rating', 'One']],
#  ['Everydata: The Misinformation Hidden in the Little Data You Consume Every Day',
#   54.35,
#   ['star-rating', 'Two']],
#  ["Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master",
#   37.97,
#   ['star-rating', 'Two']],
#  ['Danganronpa Volume 1', 51.99, ['star-rating', 'Four']],
#  ['Crown of Midnight (Throne of Glass #2)', 43.29, ['star-rating', 'Three']],
#  ['Codename Baboushka, Volume 1: The Conclave of Death',
#   36.72,
#   ['star-rating', 'Four']],
#  ['Camp Midnight', 17.08, ['star-rating', 'Four']],
#  ['Call the Nurse: True Stories of a Country Nurse on a Scottish Isle',
#   29.14,
#   ['star-rating', 'Five']],
#  ['Burning', 28.81, ['star-rating', 'Three']],
#  ['Bossypants', 49.46, ['star-rating', 'Two']],
#  ['Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))',
#   37.92,
#   ['star-rating', 'Two']],
#  ['Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3)',
#   28.09,
#   ['star-rating', 'Two']],
#  ['Algorithms to Live By: The Computer Science of Human Decisions',
#   30.81,
#   ['star-rating', 'One']],
#  ['A World of Flavor: Your Gluten Free Passport',
#   42.95,
#   ['star-rating', 'One']],
#  ['A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations',
#   56.76,
#   ['star-rating', 'Five']],
#  ['A Murder in Time', 16.64, ['star-rating', 'One']],
#  ['A Flight of Arrows (The Pathfinders #2)', 55.53, ['star-rating', 'Five']],
#  ['A Fierce and Subtle Poison', 28.13, ['star-rating', 'Four']],
#  ['A Court of Thorns and Roses (A Court of Thorns and Roses #1)',
#   52.37,
#   ['star-rating', 'One']],
#  ['(Un)Qualified: How God Uses Broken People to Do Big Things',
#   54.0,
#   ['star-rating', 'Five']],
#  ['You Are What You Love: The Spiritual Power of Habit',
#   21.87,
#   ['star-rating', 'Four']],
#  ["William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)",
#   43.3,
#   ['star-rating', 'Four']],
#  ['Tuesday Nights in 1980', 21.04, ['star-rating', 'Two']],
#  ['Tracing Numbers on a Train', 41.6, ['star-rating', 'Three']],
#  ['Throne of Glass (Throne of Glass #1)', 35.07, ['star-rating', 'Three']],
#  ['Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History',
#   59.64,
#   ['star-rating', 'One']],
#  ['Thirteen Reasons Why', 52.72, ['star-rating', 'One']],
#  ['The White Cat and the Monk: A Retelling of the Poem “Pangur Bán”',
#   58.08,
#   ['star-rating', 'Four']],
#  ['The Wedding Dress', 24.12, ['star-rating', 'One']],
#  ['The Vacationers', 42.15, ['star-rating', 'Four']],
#  ['The Third Wave: An Entrepreneur’s Vision of the Future',
#   12.61,
#   ['star-rating', 'Five']],
#  ['The Stranger', 17.44, ['star-rating', 'Four']],
#  ['The Shadow Hero (The Shadow Hero)', 33.14, ['star-rating', 'One']],
#  ['The Secret (The Secret #1)', 27.37, ['star-rating', 'Four']],
#  ['The Regional Office Is Under Attack!', 51.36, ['star-rating', 'Five']],
#  ['The Psychopath Test: A Journey Through the Madness Industry',
#   36.0,
#   ['star-rating', 'Two']],
#  ['The Project', 10.65, ['star-rating', 'One']],
#  ['The Power of Now: A Guide to Spiritual Enlightenment',
#   43.54,
#   ['star-rating', 'Two']],
#  ["The Omnivore's Dilemma: A Natural History of Four Meals",
#   38.21,
#   ['star-rating', 'Two']],
#  ['The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us',
#   37.34,
#   ['star-rating', 'Five']],
#  ['The Murder of Roger Ackroyd (Hercule Poirot #4)',
#   44.1,
#   ['star-rating', 'Four']],
#  ['The Mistake (Off-Campus #2)', 43.29, ['star-rating', 'Three']],
#  ["The Matchmaker's Playbook (Wingmen Inc. #1)",
#   55.85,
#   ['star-rating', 'One']],
#  ['The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking',
#   37.6,
#   ['star-rating', 'Two']],
#  ['The Long Shadow of Small Ghosts: Murder and Memory in an American City',
#   10.97,
#   ['star-rating', 'One']],
#  ['The Kite Runner', 41.82, ['star-rating', 'Four']],
#  ['The House by the Lake', 36.95, ['star-rating', 'One']],
#  ['The Glittering Court (The Glittering Court #1)',
#   44.28,
#   ['star-rating', 'One']],
#  ['The Girl on the Train', 55.02, ['star-rating', 'Two']],
#  ['The Genius of Birds', 17.24, ['star-rating', 'One']],
#  ['The Emerald Mystery', 23.15, ['star-rating', 'Two']],
#  ['The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First',
#   41.25,
#   ['star-rating', 'One']],
#  ["The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs.",
#   32.0,
#   ['star-rating', 'Three']],
#  ["The Artist's Way: A Spiritual Path to Higher Creativity",
#   38.49,
#   ['star-rating', 'Five']],
#  ['The Art of War', 33.34, ['star-rating', 'Five']],
#  ['The Argonauts', 10.93, ['star-rating', 'Two']],
#  ['The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job',
#   27.55,
#   ['star-rating', 'Three']],
#  ['Suddenly in Love (Lake Haven #1)', 55.99, ['star-rating', 'Two']],
#  ['Something More Than This', 16.24, ['star-rating', 'Four']],
#  ['Soft Apocalypse', 26.12, ['star-rating', 'Two']],
#  ["So You've Been Publicly Shamed", 12.23, ['star-rating', 'Two']],
#  ['Shoe Dog: A Memoir by the Creator of NIKE', 23.99, ['star-rating', 'Two']],
#  ['Shobu Samurai, Project Aryoku (#3)', 29.06, ['star-rating', 'Three']],
#  ['Secrets and Lace (Fatal Hearts #1)', 20.27, ['star-rating', 'One']],
#  ['Scarlett Epstein Hates It Here', 43.55, ['star-rating', 'Five']],
#  ['Romero and Juliet: A Tragic Tale of Love and Zombies',
#   36.94,
#   ['star-rating', 'One']],
#  ['Redeeming Love', 20.47, ['star-rating', 'Five']],
#  ['Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form',
#   41.06,
#   ['star-rating', 'One']],
#  ['Poems That Make Grown Women Cry', 14.19, ['star-rating', 'Four']],
#  ['Nightingale, Sing', 38.28, ['star-rating', 'One']],
#  ['Night Sky with Exit Wounds', 41.05, ['star-rating', 'One']],
#  ['Mrs. Houdini', 30.25, ['star-rating', 'Five']],
#  ['Modern Romance', 28.26, ['star-rating', 'Five']],
#  ['Miss Peregrine’s Home for Peculiar Children (Miss Peregrine’s Peculiar Children #1)',
#   10.76,
#   ['star-rating', 'One']],
#  ['Louisa: The Extraordinary Life of Mrs. Adams',
#   16.85,
#   ['star-rating', 'Two']],
#  ['Little Red', 13.47, ['star-rating', 'Three']],
#  ['Library of Souls (Miss Peregrine’s Peculiar Children #3)',
#   48.56,
#   ['star-rating', 'Five']],
#  ['Large Print Heart of the Pride', 19.15, ['star-rating', 'Two']],
#  ['I Had a Nice Time And Other Lies...: How to find love & sh*t like that',
#   57.36,
#   ['star-rating', 'Four']],
#  ['Hollow City (Miss Peregrine’s Peculiar Children #2)',
#   42.98,
#   ['star-rating', 'One']],
#  ['Grumbles', 22.16, ['star-rating', 'Two']],
#  ['Full Moon over Noah’s Ark: An Odyssey to Mount Ararat and Beyond',
#   49.43,
#   ['star-rating', 'Four']],
#  ['Frostbite (Vampire Academy #2)', 29.99, ['star-rating', 'Five']],
#  ['Follow You Home', 21.36, ['star-rating', 'One']],
#  ['First Steps for New Christians (Print Edition)',
#   29.0,
#   ['star-rating', 'One']],
#  ['Finders Keepers (Bill Hodges Trilogy #2)', 53.53, ['star-rating', 'Five']],
#  ['Fables, Vol. 1: Legends in Exile (Fables #1)',
#   41.62,
#   ['star-rating', 'Four']],
#  ['Eureka Trivia 6.0', 54.59, ['star-rating', 'Four']],
#  ['Drive: The Surprising Truth About What Motivates Us',
#   34.95,
#   ['star-rating', 'Four']],
#  ['Done Rubbed Out (Reightman & Bailey #1)', 37.72, ['star-rating', 'Five']],
#  ['Doing It Over (Most Likely To #1)', 35.61, ['star-rating', 'Three']],
#  ['Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals',
#   42.16,
#   ['star-rating', 'Three']],
#  ['Dark Notes', 19.19, ['star-rating', 'Five']],
#  ['Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead',
#   19.43,
#   ['star-rating', 'Three']],
#  ['Close to You', 49.46, ['star-rating', 'Four']],
#  ['Chasing Heaven: What Dying Taught Me About Living',
#   37.8,
#   ['star-rating', 'Two']],
#  ['Big Magic: Creative Living Beyond Fear', 30.8, ['star-rating', 'Three']],
#  ['Becoming Wise: An Inquiry into the Mystery and Art of Living',
#   27.43,
#   ['star-rating', 'Two']],
#  ['Beauty Restored (Riley Family Legacy Novellas #3)',
#   11.11,
#   ['star-rating', 'Two']],
#  ['Batman: The Long Halloween (Batman)', 36.5, ['star-rating', 'Two']],
#  ['Batman: The Dark Knight Returns (Batman)', 15.38, ['star-rating', 'Five']],
#  ["Ayumi's Violin", 15.48, ['star-rating', 'Two']],
#  ['Anonymous', 46.82, ['star-rating', 'Four']],
#  ['Amy Meets the Saints and Sages', 18.46, ['star-rating', 'Three']],
#  ['Amid the Chaos', 36.58, ['star-rating', 'One']],
#  ['Amatus', 50.54, ['star-rating', 'Five']],
#  ['Agnostic: A Spirited Manifesto', 12.51, ['star-rating', 'Five']],
#  ['Zealot: The Life and Times of Jesus of Nazareth',
#   24.7,
#   ['star-rating', 'Three']],
#  ['You (You #1)', 43.61, ['star-rating', 'Five']],
#  ['Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)',
#   37.34,
#   ['star-rating', 'Four']],
#  ['Wild Swans', 14.36, ['star-rating', 'Two']],
#  ['Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond',
#   52.65,
#   ['star-rating', 'Four']],
#  ['Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity',
#   38.2,
#   ['star-rating', 'Four']],
#  ["What's It Like in Space?: Stories from Astronauts Who've Been There",
#   19.6,
#   ['star-rating', 'Two']],
#  ['We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1)',
#   53.9,
#   ['star-rating', 'One']],
#  ["Walt Disney's Alice in Wonderland", 12.96, ['star-rating', 'Five']],
#  ['V for Vendetta (V for Vendetta Complete)', 37.1, ['star-rating', 'Four']],
#  ['Until Friday Night (The Field Party #1)', 46.31, ['star-rating', 'Two']],
#  ['Unbroken: A World War II Story of Survival, Resilience, and Redemption',
#   45.95,
#   ['star-rating', 'Two']],
#  ['Twenty Yawns', 22.08, ['star-rating', 'Two']],
#  ['Through the Woods', 25.38, ['star-rating', 'Two']],
#  ['This Is Where It Ends', 27.12, ['star-rating', 'Two']],
#  ['The Year of Magical Thinking', 43.04, ['star-rating', 'Two']],
#  ['The Wright Brothers', 56.8, ['star-rating', 'Four']],
#  ["The White Queen (The Cousins' War #1)", 25.91, ['star-rating', 'Five']],
#  ["The Wedding Pact (The O'Malleys #2)", 32.61, ['star-rating', 'Three']],
#  ['The Time Keeper', 27.88, ['star-rating', 'Five']],
#  ['The Testament of Mary', 52.67, ['star-rating', 'Four']],
#  ['The Star-Touched Queen', 46.02, ['star-rating', 'Five']],
#  ['The Songs of the Gods', 44.48, ['star-rating', 'Five']],
#  ['The Song of Achilles', 37.4, ['star-rating', 'Five']],
#  ['The Rosie Project (Don Tillman #1)', 54.04, ['star-rating', 'One']],
#  ['The Power of Habit: Why We Do What We Do in Life and Business',
#   16.88,
#   ['star-rating', 'Three']],
#  ['The Marriage of Opposites', 28.08, ['star-rating', 'Four']],
#  ['The Lucifer Effect: Understanding How Good People Turn Evil',
#   10.4,
#   ['star-rating', 'One']],
#  ['The Long Haul (Diary of a Wimpy Kid #9)', 44.07, ['star-rating', 'One']],
#  ['The Loney', 23.4, ['star-rating', 'One']],
#  ['The Literature Book (Big Ideas Simply Explained)',
#   17.43,
#   ['star-rating', 'Three']],
#  ['The Last Mile (Amos Decker #2)', 54.21, ['star-rating', 'Two']],
#  ['The Immortal Life of Henrietta Lacks', 40.67, ['star-rating', 'Two']],
#  ['The Hidden Oracle (The Trials of Apollo #1)',
#   52.26,
#   ['star-rating', 'Two']],
#  ['The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Recipes Kids Can Make to Stay Healthy and Save the Earth',
#   28.77,
#   ['star-rating', 'Three']],
#  ['The Guilty (Will Robie #4)', 13.82, ['star-rating', 'Two']],
#  ['The First Hostage (J.B. Collins #2)', 25.85, ['star-rating', 'Three']],
#  ['The Dovekeepers', 48.78, ['star-rating', 'One']],
#  ['The Darkest Lie', 35.35, ['star-rating', 'Five']],
#  ['The Bane Chronicles (The Bane Chronicles #1-11)',
#   44.73,
#   ['star-rating', 'Four']],
#  ['The Bad-Ass Librarians of Timbuktu: And Their Race to Save the World’s Most Precious Manuscripts',
#   15.77,
#   ['star-rating', 'One']],
#  ['The 14th Colony (Cotton Malone #11)', 39.24, ['star-rating', 'One']],
#  ['That Darkness (Gardiner and Renner #1)', 13.92, ['star-rating', 'One']],
#  ['Tastes Like Fear (DI Marnie Rome #3)', 10.69, ['star-rating', 'One']],
#  ['Take Me with You', 45.21, ['star-rating', 'Three']],
#  ['Swell: A Year of Waves', 45.58, ['star-rating', 'One']],
#  ['Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)',
#   11.89,
#   ['star-rating', 'Five']],
#  ['Still Life with Bread Crumbs', 26.41, ['star-rating', 'Three']],
#  ['Steve Jobs', 39.5, ['star-rating', 'Five']],
#  ['Sorting the Beef from the Bull: The Science of Food Fraud Forensics',
#   44.74,
#   ['star-rating', 'Four']],
#  ['Someone Like You (The Harrisons #2)', 52.79, ['star-rating', 'Five']],
#  ['So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)',
#   35.43,
#   ['star-rating', 'Four']],
#  ['Shtum', 55.84, ['star-rating', 'Four']],
#  ['See America: A Celebration of Our National Parks & Treasured Sites',
#   48.87,
#   ['star-rating', 'Three']],
#  ['salt.', 46.78, ['star-rating', 'Four']],
#  ['Robin War', 47.82, ['star-rating', 'Three']],
#  ['Red Hood/Arsenal, Vol. 1: Open for Business (Red Hood/Arsenal #1)',
#   25.48,
#   ['star-rating', 'Two']],
#  ['Rain Fish', 23.57, ['star-rating', 'Three']],
#  ['Quarter Life Poetry: Poems for the Young, Broke and Hangry',
#   50.89,
#   ['star-rating', 'Five']],
#  ['Pet Sematary', 10.56, ['star-rating', 'Three']],
#  ['Overload: How to Unplug, Unwind, and Unleash Yourself from the Pressure of Stress',
#   52.15,
#   ['star-rating', 'Three']],
#  ['Once Was a Time', 18.28, ['star-rating', 'Two']],
#  ['Old School (Diary of a Wimpy Kid #10)', 11.83, ['star-rating', 'Five']],
#  ['No Dream Is Too High: Life Lessons From a Man Who Walked on the Moon',
#   21.95,
#   ['star-rating', 'Two']],
#  ['Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42 (Naruto: Omnibus #14)',
#   38.39,
#   ['star-rating', 'Two']],
#  ['My Name Is Lucy Barton', 41.56, ['star-rating', 'One']],
#  ['My Mrs. Brown', 24.48, ['star-rating', 'Three']],
#  ['My Kind of Crazy', 40.36, ['star-rating', 'One']],
#  ['Mr. Mercedes (Bill Hodges Trilogy #1)', 28.9, ['star-rating', 'One']],
#  ['More Than Music (Chasing the Dream #1)', 37.61, ['star-rating', 'Two']],
#  ['Made to Stick: Why Some Ideas Survive and Others Die',
#   38.85,
#   ['star-rating', 'Five']],
#  ['Luis Paints the World', 53.95, ['star-rating', 'Three']],
#  ['Luckiest Girl Alive', 49.83, ['star-rating', 'Three']],
#  ['Lowriders to the Center of the Earth (Lowriders in Space #2)',
#   51.51,
#   ['star-rating', 'Two']],
#  ['Love Is a Mix Tape (Music #1)', 18.03, ['star-rating', 'One']],
#  ['Looking for Lovely: Collecting the Moments that Matter',
#   29.14,
#   ['star-rating', 'Five']],
#  ['Living Leadership by Insight: A Good Leader Achieves, a Great Leader Builds Monuments',
#   46.91,
#   ['star-rating', 'Four']],
#  ['Let It Out: A Journey Through Journaling', 26.79, ['star-rating', 'Five']],
#  ['Lady Midnight (The Dark Artifices #1)', 16.28, ['star-rating', 'Five']],
#  ["It's All Easy: Healthy, Delicious Weeknight Meals in under 30 Minutes",
#   19.55,
#   ['star-rating', 'One']],
#  ['Island of Dragons (Unwanteds #7)', 29.65, ['star-rating', 'One']],
#  ["I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches from a Life Under Construction",
#   25.98,
#   ['star-rating', 'Four']],
#  ['I Am Pilgrim (Pilgrim #1)', 10.6, ['star-rating', 'Four']],
#  ['Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened',
#   14.75,
#   ['star-rating', 'Five']],
#  ['Hush, Hush (Hush, Hush #1)', 47.02, ['star-rating', 'Three']],
#  ['Hold Your Breath (Search and Rescue #1)', 28.82, ['star-rating', 'One']],
#  ['Hamilton: The Revolution', 58.79, ['star-rating', 'Three']],
#  ['Greek Mythic History', 10.23, ['star-rating', 'Five']],
#  ['God: The Most Unpleasant Character in All Fiction',
#   30.03,
#   ['star-rating', 'Five']],
#  ['Glory over Everything: Beyond The Kitchen House',
#   45.84,
#   ['star-rating', 'Three']],
#  ['Feathers: Displays of Brilliant Plumage', 49.05, ['star-rating', 'Three']],
#  ['Far & Away: Places on the Brink of Change: Seven Continents, Twenty-Five Years',
#   15.06,
#   ['star-rating', 'Four']],
#  ['Every Last Word', 46.47, ['star-rating', 'Three']],
#  ['Eligible (The Austen Project #4)', 27.09, ['star-rating', 'Three']],
#  ['El Deafo', 57.62, ['star-rating', 'Five']],
#  ['Eight Hundred Grapes', 14.39, ['star-rating', 'Four']],
#  ['Eaternity: More than 150 Deliciously Easy Vegan Recipes for a Long, Healthy, Satisfied, Joyful Life',
#   51.75,
#   ['star-rating', 'Five']],
#  ['Eat Fat, Get Thin', 54.07, ['star-rating', 'Two']],
#  ["Don't Get Caught", 55.35, ['star-rating', 'One']],
#  ['Doctor Sleep (The Shining #2)', 40.12, ['star-rating', 'Two']],
#  ['Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy Jackson & Kane Chronicles Crossover #1-3)',
#   37.51,
#   ['star-rating', 'Five']],
#  ['Dear Mr. Knightley', 11.21, ['star-rating', 'Five']],
#  ['Daily Fantasy Sports', 36.58, ['star-rating', 'One']],
#  ['Crazy Love: Overwhelmed by a Relentless God',
#   47.72,
#   ['star-rating', 'Two']],
#  ['Cometh the Hour (The Clifton Chronicles #6)',
#   25.01,
#   ['star-rating', 'Three']],
#  ['Code Name Verity (Code Name Verity #1)', 22.13, ['star-rating', 'Four']],
#  ['Clockwork Angel (The Infernal Devices #1)', 44.14, ['star-rating', 'One']],
#  ['City of Glass (The Mortal Instruments #3)', 56.02, ['star-rating', 'Four']],
#  ['City of Fallen Angels (The Mortal Instruments #4)',
#   11.23,
#   ['star-rating', 'Four']],
#  ['City of Bones (The Mortal Instruments #1)', 43.28, ['star-rating', 'One']],
#  ['City of Ashes (The Mortal Instruments #2)', 47.27, ['star-rating', 'One']],
#  ['Cell', 20.29, ['star-rating', 'Four']],
#  ['Catching Jordan (Hundred Oaks)', 50.83, ['star-rating', 'Three']],
#  ['Carry On, Warrior: Thoughts on Life Unarmed',
#   31.85,
#   ['star-rating', 'Three']],
#  ['Carrie', 46.23, ['star-rating', 'Two']],
#  ['Buying In: The Secret Dialogue Between What We Buy and Who We Are',
#   37.8,
#   ['star-rating', 'Four']],
#  ['Brain on Fire: My Month of Madness', 49.32, ['star-rating', 'Five']],
#  ['Batman: Europa', 32.01, ['star-rating', 'Two']],
#  ['Barefoot Contessa Back to Basics', 28.01, ['star-rating', 'One']],
#  ["Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again",
#   50.62,
#   ['star-rating', 'Five']],
#  ['Balloon Animals', 17.03, ['star-rating', 'Three']],
#  ['Art Ops Vol. 1', 48.8, ['star-rating', 'Three']],
#  ['Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe #1)',
#   58.14,
#   ['star-rating', 'Four']],
#  ['Angels Walking (Angels Walking #1)', 34.2, ['star-rating', 'Two']],
#  ['Angels & Demons (Robert Langdon #1)', 51.48, ['star-rating', 'Three']],
#  ['All the Light We Cannot See', 29.87, ['star-rating', 'Five']],
#  ['Adulthood Is a Myth: A "Sarah\'s Scribbles" Collection',
#   10.9,
#   ['star-rating', 'Two']],
#  ['Abstract City', 56.37, ['star-rating', 'Five']],
#  ['A Time of Torment (Charlie Parker #14)', 48.35, ['star-rating', 'Five']],
#  ['A Study in Scarlet (Sherlock Holmes #1)', 16.73, ['star-rating', 'Two']],
#  ['A Series of Catastrophes and Miracles: A True Story of Love, Science, and Cancer',
#   56.48,
#   ['star-rating', 'Two']],
#  ["A People's History of the United States", 40.79, ['star-rating', 'Two']],
#  ['A Man Called Ove', 39.72, ['star-rating', 'One']],
#  ['A Distant Mirror: The Calamitous 14th Century',
#   14.58,
#   ['star-rating', 'Three']],
#  ['A Brush of Wings (Angels Walking #3)', 55.51, ['star-rating', 'One']],
#  ['1491: New Revelations of the Americas Before Columbus',
#   21.8,
#   ['star-rating', 'Three']],
#  ['The Three Searches, Meaning, and the Story',
#   13.33,
#   ['star-rating', 'Three']],
#  ['Searching for Meaning in Gailana', 38.73, ['star-rating', 'One']],
#  ['Rook', 37.86, ['star-rating', 'Four']],
#  ['My Kitchen Year: 136 Recipes That Saved My Life',
#   11.53,
#   ['star-rating', 'Two']],
#  ['13 Hours: The Inside Account of What Really Happened In Benghazi',
#   27.06,
#   ['star-rating', 'One']],
#  ["Will You Won't You Want Me?", 13.86, ['star-rating', 'Three']],
#  ['Tipping Point for Planet Earth: How Close Are We to the Edge?',
#   37.55,
#   ['star-rating', 'One']],
#  ['The Star-Touched Queen', 32.3, ['star-rating', 'Five']],
#  ['The Silent Sister (Riley MacPherson #1)', 46.29, ['star-rating', 'Five']],
#  ['The Midnight Watch: A Novel of the Titanic and the Californian',
#   26.2,
#   ['star-rating', 'One']],
#  ['The Lonely City: Adventures in the Art of Being Alone',
#   33.26,
#   ['star-rating', 'Two']],
#  ['The Gray Rhino: How to Recognize and Act on the Obvious Dangers We Ignore',
#   59.15,
#   ['star-rating', 'Four']],
#  ['The Golden Condom: And Other Essays on Love Lost and Found',
#   39.43,
#   ['star-rating', 'One']],
#  ['The Epidemic (The Program 0.6)', 14.44, ['star-rating', 'Five']],
#  ['The Dinner Party', 56.54, ['star-rating', 'Two']],
#  ['The Diary of a Young Girl', 59.9, ['star-rating', 'Three']],
#  ['The Children', 11.88, ['star-rating', 'Three']],
#  ['Stars Above (The Lunar Chronicles #4.5)', 48.05, ['star-rating', 'Two']],
#  ['Snatched: How A Drug Queen Went Undercover for the DEA and Was Kidnapped By Colombian Guerillas',
#   21.21,
#   ['star-rating', 'Three']],
#  ['Raspberry Pi Electronics Projects for the Evil Genius',
#   49.67,
#   ['star-rating', 'Four']],
#  ['Quench Your Own Thirst: Business Lessons Learned Over a Beer or Two',
#   43.14,
#   ['star-rating', 'One']],
#  ['Psycho: Sanitarium (Psycho #1.5)', 36.97, ['star-rating', 'Five']],
#  ['Poisonous (Max Revere Novels #3)', 26.8, ['star-rating', 'Three']],
#  ['One with You (Crossfire #5)', 15.71, ['star-rating', 'Four']],
#  ['No Love Allowed (Dodge Cove #1)', 54.65, ['star-rating', 'Four']],
#  ['Murder at the 42nd Street Library (Raymond Ambler #1)',
#   54.36,
#   ['star-rating', 'Four']],
#  ['Most Wanted', 35.28, ['star-rating', 'Three']],
#  ['Love, Lies and Spies', 20.55, ['star-rating', 'Two']],
#  ['How to Speak Golf: An Illustrated Guide to Links Lingo',
#   58.32,
#   ['star-rating', 'Five']],
#  ['Hide Away (Eve Duncan #20)', 11.84, ['star-rating', 'One']],
#  ['Furiously Happy: A Funny Book About Horrible Things',
#   41.46,
#   ['star-rating', 'Four']],
#  ['Everyday Italian: 125 Simple and Delicious Recipes',
#   20.1,
#   ['star-rating', 'Five']],
#  ["Equal Is Unfair: America's Misguided Fight Against Income Inequality",
#   56.86,
#   ['star-rating', 'One']],
#  ['Eleanor & Park', 56.51, ['star-rating', 'Five']],
#  ['Dirty (Dive Bar #1)', 40.83, ['star-rating', 'Four']],
#  ['Can You Keep a Secret? (Fear Street Relaunch #4)',
#   48.64,
#   ['star-rating', 'One']],
#  ['Boar Island (Anna Pigeon #19)', 59.48, ['star-rating', 'Three']],
#  ['A Paris Apartment', 39.01, ['star-rating', 'Four']],
#  ['A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, Crisps, and More Topped with Ice Cream, Gelato, Frozen Custard, and More',
#   38.77,
#   ['star-rating', 'One']],
#  ['Troublemaker: Surviving Hollywood and Scientology',
#   48.39,
#   ['star-rating', 'Two']],
#  ['The Widow', 27.26, ['star-rating', 'Two']],
#  ['The Sleep Revolution: Transforming Your Life, One Night at a Time',
#   11.68,
#   ['star-rating', 'Four']],
#  ['The Improbability of Love', 59.45, ['star-rating', 'One']],
#  ['The Art of Startup Fundraising', 21.0, ['star-rating', 'Three']],
#  ['Take Me Home Tonight (Rock Star Romance #3)',
#   53.98,
#   ['star-rating', 'Three']],
#  ['Sleeping Giants (Themis Files #1)', 48.74, ['star-rating', 'One']],
#  ['Setting the World on Fire: The Brief, Astonishing Life of St. Catherine of Siena',
#   21.15,
#   ['star-rating', 'Two']],
#  ['Playing with Fire', 13.71, ['star-rating', 'Three']],
#  ['Off the Hook (Fishing for Trouble #1)', 47.67, ['star-rating', 'Three']],
#  ['Mothering Sunday', 13.34, ['star-rating', 'Two']],
#  ['Mother, Can You Not?', 16.89, ['star-rating', 'Five']],
#  ['M Train', 27.18, ['star-rating', 'One']],
#  ['Lilac Girls', 17.28, ['star-rating', 'Two']],
#  ['Lies and Other Acts of Love', 45.14, ['star-rating', 'One']],
#  ['Lab Girl', 40.85, ['star-rating', 'One']],
#  ['Keep Me Posted', 20.46, ['star-rating', 'Four']],
#  ["It Didn't Start with You: How Inherited Family Trauma Shapes Who We Are and How to End the Cycle",
#   56.27,
#   ['star-rating', 'Three']],
#  ['Grey (Fifty Shades #4)', 48.49, ['star-rating', 'Four']],
#  ['Exit, Pursued by a Bear', 51.34, ['star-rating', 'Four']],
#  ['Daredevils', 16.34, ['star-rating', 'Three']],
#  ['Cravings: Recipes for What You Want to Eat',
#   20.5,
#   ['star-rating', 'Three']],
#  ['Born for This: How to Find the Work You Were Meant to Do',
#   21.59,
#   ['star-rating', 'Five']],
#  ['Arena', 21.36, ['star-rating', 'Four']],
#  ['Adultery', 20.88, ['star-rating', 'Five']],
#  ["A Mother's Reckoning: Living in the Aftermath of Tragedy",
#   19.53,
#   ['star-rating', 'Three']],
#  ["A Gentleman's Position (Society of Gentlemen #3)",
#   14.75,
#   ['star-rating', 'Five']],
#  ['11/22/63', 48.48, ['star-rating', 'Three']],
#  ['10% Happier: How I Tamed the Voice in My Head, Reduced Stress Without Losing My Edge, and Found Self-Help That Actually Works',
#   24.57,
#   ['star-rating', 'Two']],
#  ['10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!',
#   49.71,
#   ['star-rating', 'Five']],
#  ['Without Shame', 48.27, ['star-rating', 'Five']],
#  ['Watchmen', 58.05, ['star-rating', 'Four']],
#  ['Unlimited Intuition Now', 58.87, ['star-rating', 'Four']],
#  ['Underlying Notes', 11.82, ['star-rating', 'Two']],
#  ['The Shack', 28.03, ['star-rating', 'One']],
#  ['The New Brand You: Your New Image Makes the Sale for You',
#   44.05,
#   ['star-rating', 'Five']],
#  ['The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, New York',
#   12.34,
#   ['star-rating', 'Four']],
#  ['The Flowers Lied', 16.68, ['star-rating', 'Two']],
#  ['The Fabric of the Cosmos: Space, Time, and the Texture of Reality',
#   55.91,
#   ['star-rating', 'One']],
#  ['The Book of Mormon', 24.57, ['star-rating', 'Three']],
#  ['The Art and Science of Low Carbohydrate Living',
#   52.98,
#   ['star-rating', 'Five']],
#  ['The Alien Club', 54.4, ['star-rating', 'One']],
#  ['Suzie Snowflake: One beautiful flake (a self-esteem story)',
#   54.81,
#   ['star-rating', 'Five']],
#  ['Nap-a-Roo', 25.08, ['star-rating', 'One']],
#  ['NaNo What Now? Finding your editing process, revising your NaNoWriMo book and building a writing career through publishing and beyond',
#   10.41,
#   ['star-rating', 'Four']],
#  ['Modern Day Fables', 47.44, ['star-rating', 'Two']],
#  ["If I Gave You God's Phone Number....: Searching for Spirituality in America",
#   20.91,
#   ['star-rating', 'One']],
#  ['Fruits Basket, Vol. 9 (Fruits Basket #9)', 33.95, ['star-rating', 'Four']],
#  ['Dress Your Family in Corduroy and Denim', 43.68, ['star-rating', 'Three']],
#  ["Don't Forget Steven", 33.23, ['star-rating', 'One']],
#  ["Chernobyl 01:23:40: The Incredible True Story of the World's Worst Nuclear Disaster",
#   35.92,
#   ['star-rating', 'Two']],
#  ['Art and Fear: Observations on the Perils (and Rewards) of Artmaking',
#   48.63,
#   ['star-rating', 'Four']],
#  ['A Shard of Ice (The Black Symphony Saga #1)',
#   56.63,
#   ['star-rating', 'Three']],
#  ["A Hero's Curse (The Unseen Chronicles #1)",
#   50.49,
#   ['star-rating', 'Three']],
#  ['23 Degrees South: A Tropical Tale of Changing Whether...',
#   35.79,
#   ['star-rating', 'Two']],
#  ['Zero to One: Notes on Startups, or How to Build the Future',
#   34.06,
#   ['star-rating', 'Three']],
#  ['Why Not Me?', 17.76, ['star-rating', 'One']],
#  ['When Breath Becomes Air', 39.36, ['star-rating', 'Two']],
#  ['Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel',
#   36.94,
#   ['star-rating', 'Two']],
#  ['The Unlikely Pilgrimage of Harold Fry (Harold Fry #1)',
#   43.62,
#   ['star-rating', 'Five']],
#  ['The New Drawing on the Right Side of the Brain',
#   43.02,
#   ['star-rating', 'Three']],
#  ["The Midnight Assassin: Panic, Scandal, and the Hunt for America's First Serial Killer",
#   28.45,
#   ['star-rating', 'Four']],
#  ['The Martian (The Martian #1)', 41.39, ['star-rating', 'Two']],
#  ['The High Mountains of Portugal', 51.15, ['star-rating', 'One']],
#  ['The Grownup', 35.88, ['star-rating', 'One']],
#  ["The E-Myth Revisited: Why Most Small Businesses Don't Work and What to Do About It",
#   36.91,
#   ['star-rating', 'One']],
#  ['South of Sunshine', 28.93, ['star-rating', 'One']],
#  ['Smarter Faster Better: The Secrets of Being Productive in Life and Business',
#   38.89,
#   ['star-rating', 'Five']],
#  ['Silence in the Dark (Logan Point #4)', 58.33, ['star-rating', 'Three']],
#  ['Shadows of the Past (Logan Point #1)', 39.67, ['star-rating', 'Five']],
#  ['Roller Girl', 14.1, ['star-rating', 'Five']],
#  ['Rising Strong', 21.82, ['star-rating', 'Three']],
#  ['Proofs of God: Classical Arguments from Tertullian to Barth',
#   54.21,
#   ['star-rating', 'One']],
#  ['Please Kill Me: The Uncensored Oral History of Punk',
#   31.19,
#   ['star-rating', 'Four']],
#  ['Out of Print: City Lights Spotlight No. 14',
#   53.64,
#   ['star-rating', 'Five']],
#  ['My Life Next Door (My Life Next Door )', 36.39, ['star-rating', 'Five']],
#  ["Miller's Valley", 58.54, ['star-rating', 'Two']],
#  ["Man's Search for Meaning", 29.48, ['star-rating', 'Three']],
#  ["Love That Boy: What Two Presidents, Eight Road Trips, and My Son Taught Me About a Parent's Expectations",
#   25.06,
#   ['star-rating', 'Two']],
#  ['Living Forward: A Proven Plan to Stop Drifting and Get the Life You Want',
#   12.55,
#   ['star-rating', 'Three']],
#  ['Les Fleurs du Mal', 29.04, ['star-rating', 'Five']],
#  ['Left Behind (Left Behind #1)', 40.72, ['star-rating', 'Two']],
#  ["Kill 'Em and Leave: Searching for James Brown and the American Soul",
#   45.05,
#   ['star-rating', 'Five']],
#  ['Kierkegaard: A Christian Missionary to Christians',
#   47.13,
#   ['star-rating', 'One']],
#  ['John Vassos: Industrial Design for Modern Life',
#   20.22,
#   ['star-rating', 'Four']],
#  ["I'll Give You the Sun", 56.48, ['star-rating', 'One']],
#  ['I Will Find You', 44.21, ['star-rating', 'One']],
#  ['Hystopia: A Novel', 21.96, ['star-rating', 'Four']],
#  ['Howl and Other Poems', 40.45, ['star-rating', 'Two']],
#  ['History of Beauty', 10.29, ['star-rating', 'Four']],
#  ["Heaven is for Real: A Little Boy's Astounding Story of His Trip to Heaven and Back",
#   52.86,
#   ['star-rating', 'Two']],
#  ['Future Shock (Future Shock #1)', 55.65, ['star-rating', 'Five']],
#  ["Ender's Game (The Ender Quintet #1)", 43.64, ['star-rating', 'One']],
#  ['Diary of a Citizen Scientist: Chasing Tiger Beetles and Other New Ways of Engaging the World',
#   28.41,
#   ['star-rating', 'One']],
#  ['Death by Leisure: A Cautionary Tale', 37.51, ['star-rating', 'Four']],
#  ['Brilliant Beacons: A History of the American Lighthouse',
#   11.45,
#   ['star-rating', 'Three']],
#  ["Brazen: The Courage to Find the You That's Been Hiding",
#   19.22,
#   ['star-rating', 'Two']],
#  ['Between the World and Me', 56.91, ['star-rating', 'Four']],
#  ['Being Mortal: Medicine and What Matters in the End',
#   55.06,
#   ['star-rating', 'Four']],
#  ['A Murder Over a Girl: Justice, Gender, Junior High',
#   13.2,
#   ['star-rating', 'Three']],
#  ['32 Yolks', 53.63, ['star-rating', 'Two']],
#  ['"Most Blessed of the Patriarchs": Thomas Jefferson and the Empire of the Imagination',
#   44.48,
#   ['star-rating', 'Five']],
#  ['You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life',
#   12.08,
#   ['star-rating', 'Three']],
#  ['Wildlife of New York: A Five-Borough Coloring Book',
#   22.14,
#   ['star-rating', 'Two']],
#  ['What Happened on Beale Street (Secrets of the South Mysteries #2)',
#   25.37,
#   ['star-rating', 'Five']],
#  ['Unreasonable Hope: Finding Faith in the God Who Brings Purpose to Your Pain',
#   46.33,
#   ['star-rating', 'Two']],
#  ['Under the Tuscan Sun', 37.33, ['star-rating', 'Three']],
#  ["Toddlers Are A**holes: It's Not Your Fault", 25.55, ['star-rating', 'One']],
#  ["The Year of Living Biblically: One Man's Humble Quest to Follow the Bible as Literally as Possible",
#   34.72,
#   ['star-rating', 'One']],
#  ['The Whale', 35.96, ['star-rating', 'Four']],
#  ['The Story of Art', 41.14, ['star-rating', 'Four']],
#  ['The Origin of Species', 10.01, ['star-rating', 'Four']],
#  ['The Great Gatsby', 36.05, ['star-rating', 'Four']],
#  ['The Good Girl', 49.03, ['star-rating', 'Three']],
#  ['The Glass Castle', 16.24, ['star-rating', 'One']],
#  ["The Faith of Christopher Hitchens: The Restless Soul of the World's Most Notorious Atheist",
#   39.55,
#   ['star-rating', 'One']],
#  ['The Drowning Girls', 35.67, ['star-rating', 'Three']],
#  ['The Constant Princess (The Tudor Court #1)',
#   16.62,
#   ['star-rating', 'Three']],
#  ['The Bourne Identity (Jason Bourne #1)', 42.78, ['star-rating', 'Four']],
#  ["The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1)",
#   52.3,
#   ['star-rating', 'Five']],
#  ['The Art Book', 32.34, ['star-rating', 'Two']],
#  ['The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change',
#   33.17,
#   ['star-rating', 'Four']],
#  ['Team of Rivals: The Political Genius of Abraham Lincoln',
#   20.12,
#   ['star-rating', 'Five']],
#  ['Steal Like an Artist: 10 Things Nobody Told You About Being Creative',
#   20.9,
#   ['star-rating', 'Two']],
#  ['Sit, Stay, Love', 20.9, ['star-rating', 'Three']],
#  ['Sister Dear', 40.2, ['star-rating', 'Four']],
#  ['Shrunken Treasures: Literary Classics, Short, Sweet, and Silly',
#   52.87,
#   ['star-rating', 'Three']],
#  ['Rich Dad, Poor Dad', 51.74, ['star-rating', 'One']],
#  ['Raymie Nightingale', 34.41, ['star-rating', 'Two']],
#  ['Playing from the Heart', 32.38, ['star-rating', 'One']],
#  ['Nightstruck: A Novel', 50.35, ['star-rating', 'Four']],
#  ['Naturally Lean: 125 Nourishing Gluten-Free, Plant-Based Recipes--All Under 300 Calories',
#   11.38,
#   ['star-rating', 'Five']],
#  ['Meternity', 43.58, ['star-rating', 'Three']],
#  ['Memoirs of a Geisha', 49.67, ['star-rating', 'Three']],
#  ['Like Never Before (Walker Family #2)', 28.77, ['star-rating', 'Two']],
#  ['Life of Pi', 13.22, ['star-rating', 'Four']],
#  ['Leave This Song Behind: Teen Poetry at Its Best',
#   51.17,
#   ['star-rating', 'Five']],
#  ["King's Folly (The Kinsman Chronicles #1)", 39.61, ['star-rating', 'Five']],
#  ['John Adams', 57.43, ['star-rating', 'Four']],
#  ['How to Cook Everything Vegetarian: Simple Meatless Recipes for Great Food (How to Cook Everything)',
#   46.01,
#   ['star-rating', 'Four']],
#  ['How to Be a Domestic Goddess: Baking and the Art of Comfort Cooking',
#   28.25,
#   ['star-rating', 'Two']],
#  ['Good in Bed (Cannie Shapiro #1)', 37.05, ['star-rating', 'Five']],
#  ['Fruits Basket, Vol. 7 (Fruits Basket #7)', 19.57, ['star-rating', 'One']],
#  ['For the Love: Fighting for Grace in a World of Impossible Standards',
#   45.13,
#   ['star-rating', 'Three']],
#  ['Finding God in the Ruins: How God Redeems Pain',
#   46.64,
#   ['star-rating', 'Two']],
#  ['Every Heart a Doorway (Every Heart A Doorway #1)',
#   12.16,
#   ['star-rating', 'Five']],
#  ['Delivering the Truth (Quaker Midwife Mystery #1)',
#   20.89,
#   ['star-rating', 'Four']],
#  ['Counted With the Stars (Out from Egypt #1)',
#   17.97,
#   ['star-rating', 'Five']],
#  ['Chronicles, Vol. 1', 52.6, ['star-rating', 'Two']],
#  ['Blue Like Jazz: Nonreligious Thoughts on Christian Spirituality',
#   25.77,
#   ['star-rating', 'One']],
#  ['Benjamin Franklin: An American Life', 48.19, ['star-rating', 'Three']],
#  ['At The Existentialist Café: Freedom, Being, and apricot cocktails with: Jean-Paul Sartre, Simone de Beauvoir, Albert Camus, Martin Heidegger, Edmund Husserl, Karl Jaspers, Maurice Merleau-Ponty and others',
#   29.93,
#   ['star-rating', 'Five']],
#  ['A Summer In Europe', 44.34, ['star-rating', 'Two']],
#  ['A Short History of Nearly Everything', 52.4, ['star-rating', 'Five']],
#  ['A Gathering of Shadows (Shades of Magic #2)',
#   44.81,
#   ['star-rating', 'Four']],
#  ['The Sound Of Love', 57.84, ['star-rating', 'Five']],
#  ['The Rise and Fall of the Third Reich: A History of Nazi Germany',
#   39.67,
#   ['star-rating', 'Two']],
#  ['The Perks of Being a Wallflower', 55.02, ['star-rating', 'Three']],
#  ['The Mysterious Affair at Styles (Hercule Poirot #1)',
#   24.8,
#   ['star-rating', 'Four']],
#  ['The Man Who Mistook His Wife for a Hat and Other Clinical Tales',
#   59.45,
#   ['star-rating', 'Four']],
#  ['The Makings of a Fatherless Child', 31.58, ['star-rating', 'Two']],
#  ['The Joy of Cooking', 43.27, ['star-rating', 'Four']],
#  ['The Invention of Wings', 37.34, ['star-rating', 'One']],
#  ['The Hobbit (Middle-Earth Universe)', 17.8, ['star-rating', 'Five']],
#  ['The Great Railway Bazaar', 30.54, ['star-rating', 'One']],
#  ['The Golden Compass (His Dark Materials #1)', 18.77, ['star-rating', 'One']],
#  ['The God Delusion', 46.85, ['star-rating', 'Three']],
#  ['The Girl You Left Behind (The Girl You Left Behind #1)',
#   15.79,
#   ['star-rating', 'One']],
#  ['The Fellowship of the Ring (The Lord of the Rings #1)',
#   10.27,
#   ['star-rating', 'Two']],
#  ['The Collected Poems of W.B. Yeats (The Collected Works of W.B. Yeats #1)',
#   15.42,
#   ['star-rating', 'Five']],
#  ['The Barefoot Contessa Cookbook', 59.92, ['star-rating', 'Five']],
#  ["Tell the Wolves I'm Home", 50.96, ['star-rating', 'Two']],
#  ['Ship Leaves Harbor: Essays on Travel by a Recovering Journeyman',
#   30.6,
#   ['star-rating', 'Three']],
#  ['Pride and Prejudice', 19.27, ['star-rating', 'Four']],
#  ['Musicophilia: Tales of Music and the Brain', 46.58, ['star-rating', 'One']],
#  ['Mere Christianity', 48.51, ['star-rating', 'Three']],
#  ['Me Before You (Me Before You #1)', 19.02, ['star-rating', 'One']],
#  ['In the Woods (Dublin Murder Squad #1)', 38.38, ['star-rating', 'Two']],
#  ['In Cold Blood', 49.98, ['star-rating', 'Four']],
#  ['How to Stop Worrying and Start Living', 46.49, ['star-rating', 'Five']],
#  ['Give It Back', 18.32, ['star-rating', 'Two']],
#  ['Girl, Interrupted', 42.14, ['star-rating', 'Three']],
#  ['Fun Home: A Family Tragicomic', 56.59, ['star-rating', 'Four']],
#  ['Fruits Basket, Vol. 6 (Fruits Basket #6)', 20.96, ['star-rating', 'Four']],
#  ['Deception Point', 40.32, ['star-rating', 'Four']],
#  ['Death Note, Vol. 6: Give-and-Take (Death Note #6)',
#   36.39,
#   ['star-rating', 'Three']],
#  ['Catherine the Great: Portrait of a Woman', 58.55, ['star-rating', 'Four']],
#  ['Better Homes and Gardens New Cook Book', 39.61, ['star-rating', 'Three']],
#  ['An Unquiet Mind: A Memoir of Moods and Madness',
#   21.3,
#   ['star-rating', 'Three']],
#  ['A Year in Provence (Provence #1)', 56.88, ['star-rating', 'Four']],
#  ['World Without End (The Pillars of the Earth #2)',
#   32.97,
#   ['star-rating', 'Four']],
#  ['Will Grayson, Will Grayson (Will Grayson, Will Grayson)',
#   47.31,
#   ['star-rating', 'Four']],
#  ['Why Save the Bankers?: And Other Essays on Our Economic and Political Crisis',
#   48.67,
#   ['star-rating', 'Two']],
#  ['Where She Went (If I Stay #2)', 41.73, ['star-rating', 'Four']],
#  ['What If?: Serious Scientific Answers to Absurd Hypothetical Questions',
#   53.68,
#   ['star-rating', 'Four']],
#  ['Two Summers', 14.64, ['star-rating', 'One']],
# ...
#  ['Seven Days in the Art World', 52.33, ['star-rating', 'Two']],
#  ['Seven Brief Lessons on Physics', 30.6, ['star-rating', 'Four']],
#  ['Scarlet (The Lunar Chronicles #2)', 14.57, ['star-rating', 'Four']],
#  ["Sarah's Key", 46.29, ['star-rating', 'One']],
#  ['Saga, Volume 3 (Saga (Collected Editions) #3)',
#   21.57,
#   ['star-rating', 'Five']],
#  ['Running with Scissors', 12.91, ['star-rating', 'Four']],
#  ['Rogue Lawyer (Rogue Lawyer #1)', 50.11, ['star-rating', 'Three']],
#  ['Rise of the Rocket Girls: The Women Who Propelled Us, from Missiles to the Moon to Mars',
#   41.67,
#   ['star-rating', 'Four']],
#  ['Rework', 44.88, ['star-rating', 'Two']],
#  ['Reservations for Two', 11.1, ['star-rating', 'Three']],
#  ['Red: The True Story of Red Riding Hood', 28.54, ['star-rating', 'Three']],
#  ['Ready Player One', 19.07, ['star-rating', 'Four']],
#  ["Quiet: The Power of Introverts in a World That Can't Stop Talking",
#   43.55,
#   ['star-rating', 'One']],
#  ['Prodigy: The Graphic Novel (Legend: The Graphic Novel #2)',
#   43.63,
#   ['star-rating', 'Three']],
#  ['Persepolis: The Story of a Childhood (Persepolis #1-2)',
#   39.13,
#   ['star-rating', 'One']],
#  ['Packing for Mars: The Curious Science of Life in the Void',
#   56.68,
#   ['star-rating', 'Two']],
#  ['Outliers: The Story of Success', 14.16, ['star-rating', 'One']],
#  ['Original Fake', 31.45, ['star-rating', 'Three']],
#  ['Orange Is the New Black', 24.61, ['star-rating', 'Two']],
#  ['One for the Money (Stephanie Plum #1)', 32.87, ['star-rating', 'Two']],
#  ['Notes from a Small Island (Notes From a Small Island #1)',
#   40.17,
#   ['star-rating', 'One']],
#  ['Night (The Night Trilogy #1)', 13.51, ['star-rating', 'One']],
#  ['Neither Here nor There: Travels in Europe',
#   38.95,
#   ['star-rating', 'Three']],
#  ['Naked', 31.69, ['star-rating', 'Three']],
#  ['Morning Star (Red Rising #3)', 29.4, ['star-rating', 'One']],
#  ['Miracles from Heaven: A Little Girl, Her Journey to Heaven, and Her Amazing Story of Healing',
#   57.83,
#   ['star-rating', 'One']],
#  ['Midnight Riot (Peter Grant/ Rivers of London - books #1)',
#   55.46,
#   ['star-rating', 'Two']],
#  ['Me Talk Pretty One Day', 57.6, ['star-rating', 'Two']],
#  ['Manuscript Found in Accra', 34.98, ['star-rating', 'Two']],
#  ['Lust & Wonder', 11.87, ['star-rating', 'Two']],
#  ['Lila (Gilead #3)', 12.47, ['star-rating', 'Three']],
#  ["Life, the Universe and Everything (Hitchhiker's Guide to the Galaxy #3)",
#   33.26,
#   ['star-rating', 'Two']],
#  ['Life Without a Recipe', 59.04, ['star-rating', 'Five']],
#  ['Life After Life', 26.13, ['star-rating', 'Two']],
#  ['Letter to a Christian Nation', 22.2, ['star-rating', 'One']],
#  ["Let's Pretend This Never Happened: A Mostly True Memoir",
#   45.11,
#   ['star-rating', 'One']],
#  ['Legend (Legend #1)', 43.69, ['star-rating', 'Four']],
#  ['Lean In: Women, Work, and the Will to Lead', 25.02, ['star-rating', 'One']],
#  ["Lamb: The Gospel According to Biff, Christ's Childhood Pal",
#   55.5,
#   ['star-rating', 'Five']],
#  ['Lady Renegades (Rebel Belle #3)', 53.04, ['star-rating', 'Five']],
#  ['Jurassic Park (Jurassic Park #1)', 44.97, ['star-rating', 'One']],
#  ["It's Never Too Late to Begin Again: Discovering Creativity and Meaning at Midlife and Beyond",
#   42.38,
#   ['star-rating', 'One']],
#  ['Is Everyone Hanging Out Without Me? (And Other Concerns)',
#   20.11,
#   ['star-rating', 'Three']],
#  ['Into the Wild', 56.7, ['star-rating', 'Five']],
#  ['Inferno (Robert Langdon #4)', 41.0, ['star-rating', 'Five']],
#  ["In the Garden of Beasts: Love, Terror, and an American Family in Hitler's Berlin",
#   28.85,
#   ['star-rating', 'Three']],
#  ['If I Run (If I Run #1)', 49.97, ['star-rating', 'Four']],
#  ["I've Got Your Number", 19.69, ['star-rating', 'One']],
#  ['I Am Malala: The Girl Who Stood Up for Education and Was Shot by the Taliban',
#   28.88,
#   ['star-rating', 'Two']],
#  ['Hungry Girl Clean & Hungry: Easy All-Natural Recipes for Healthy Eating in the Real World',
#   33.14,
#   ['star-rating', 'Three']],
#  ['House of Lost Worlds: Dinosaurs, Dynasties, and the Story of Life on Earth',
#   43.7,
#   ['star-rating', 'Two']],
#  ['House of Leaves', 54.89, ['star-rating', 'One']],
#  ['Horrible Bear!', 37.52, ['star-rating', 'Two']],
#  ['Holidays on Ice', 51.07, ['star-rating', 'Two']],
#  ['Heir to the Sky', 44.07, ['star-rating', 'Four']],
#  ['Green Eggs and Ham (Beginner Books B-16)', 10.79, ['star-rating', 'Four']],
#  ['Grayson, Vol 3: Nemesis (Grayson #3)', 42.72, ['star-rating', 'One']],
#  ['Gratitude', 26.66, ['star-rating', 'Five']],
#  ['Gone Girl', 37.6, ['star-rating', 'Five']],
#  ['Golden (Heart of Dread #3)', 42.21, ['star-rating', 'Four']],
#  ['Girl in the Blue Coat', 46.83, ['star-rating', 'Two']],
#  ['Fruits Basket, Vol. 3 (Fruits Basket #3)', 45.17, ['star-rating', 'Two']],
#  ['Friday Night Lights: A Town, a Team, and a Dream',
#   51.22,
#   ['star-rating', 'Three']],
#  ['Fire Bound (Sea Haven/Sisters of the Heart #5)',
#   21.28,
#   ['star-rating', 'Four']],
#  ['Fifty Shades Freed (Fifty Shades #3)', 15.36, ['star-rating', 'Five']],
#  ['Fellside', 38.62, ['star-rating', 'One']],
#  ['Extreme Prey (Lucas Davenport #26)', 25.4, ['star-rating', 'Three']],
#  ['Eragon (The Inheritance Cycle #1)', 43.87, ['star-rating', 'Three']],
#  ['Eclipse (Twilight #3)', 18.74, ['star-rating', 'One']],
#  ['Dune (Dune #1)', 54.86, ['star-rating', 'One']],
#  ['Dracula', 52.62, ['star-rating', 'Three']],
#  ['Do Androids Dream of Electric Sheep? (Blade Runner #1)',
#   51.48,
#   ['star-rating', 'One']],
#  ['Disrupted: My Misadventure in the Start-Up Bubble',
#   15.28,
#   ['star-rating', 'Five']],
#  ['Dead Wake: The Last Crossing of the Lusitania',
#   39.24,
#   ['star-rating', 'Five']],
#  ['David and Goliath: Underdogs, Misfits, and the Art of Battling Giants',
#   17.81,
#   ['star-rating', 'One']],
#  ['Darkfever (Fever #1)', 56.02, ['star-rating', 'One']],
#  ['Dark Places', 23.9, ['star-rating', 'Five']],
#  ['Crazy Rich Asians (Crazy Rich Asians #1)', 49.13, ['star-rating', 'Five']],
#  ['Counting Thyme', 10.62, ['star-rating', 'One']],
#  ['Cosmos', 36.17, ['star-rating', 'Two']],
#  ['Civilization and Its Discontents', 59.95, ['star-rating', 'Two']],
#  ['Cinder (The Lunar Chronicles #1)', 26.09, ['star-rating', 'One']],
#  ["Catastrophic Happiness: Finding Joy in Childhood's Messy Years",
#   37.35,
#   ['star-rating', 'Two']],
#  ['Career of Evil (Cormoran Strike #3)', 24.72, ['star-rating', 'Two']],
#  ['Breaking Dawn (Twilight #4)', 35.28, ['star-rating', 'Five']],
#  ['Brave Enough', 51.32, ['star-rating', 'Five']],
#  ['Boy Meets Boy', 21.12, ['star-rating', 'Three']],
#  ['Born to Run: A Hidden Tribe, Superathletes, and the Greatest Race the World Has Never Seen',
#   27.35,
#   ['star-rating', 'Two']],
#  ['Blink: The Power of Thinking Without Thinking',
#   21.74,
#   ['star-rating', 'Five']],
#  ['Black Flags: The Rise of ISIS', 40.87, ['star-rating', 'One']],
#  ['Black Butler, Vol. 1 (Black Butler #1)', 49.31, ['star-rating', 'One']],
#  ['Big Little Lies', 22.11, ['star-rating', 'One']],
#  ['Between Shades of Gray', 20.79, ['star-rating', 'Five']],
#  ["Best of My Love (Fool's Gold #20)", 27.41, ['star-rating', 'Two']],
#  ['Beowulf', 38.35, ['star-rating', 'Two']],
#  ['Beautiful Creatures (Caster Chronicles #1)',
#   21.55,
#   ['star-rating', 'Five']],
#  ['Awkward', 38.02, ['star-rating', 'Two']],
#  ['Ash', 22.06, ['star-rating', 'Four']],
#  ['Are We There Yet?', 10.66, ['star-rating', 'Three']],
#  ['Are We Smart Enough to Know How Smart Animals Are?',
#   56.58,
#   ['star-rating', 'One']],
#  ['Annie on My Mind', 36.83, ['star-rating', 'Five']],
#  ['And Then There Were None', 35.01, ['star-rating', 'Two']],
#  ['A Walk in the Woods: Rediscovering America on the Appalachian Trail',
#   30.48,
#   ['star-rating', 'Four']],
#  ['A Visit from the Goon Squad', 14.08, ['star-rating', 'Five']],
#  ['A Storm of Swords (A Song of Ice and Fire #3)',
#   31.22,
#   ['star-rating', 'Two']],
#  ['A Heartbreaking Work of Staggering Genius', 54.29, ['star-rating', 'Five']],
#  ['8 Keys to Mental Health Through Exercise', 31.04, ['star-rating', 'One']],
#  ['#GIRLBOSS', 50.96, ['star-rating', 'One']],
#  ['The Suffragettes (Little Black Classics, #96)',
#   11.89,
#   ['star-rating', 'Two']],
#  ['The Sense of an Ending', 31.38, ['star-rating', 'Three']],
#  ["The Sandman, Vol. 2: The Doll's House (The Sandman (volumes) #2)",
#   54.81,
#   ['star-rating', 'One']],
#  ['The Course of Love', 16.78, ['star-rating', 'Three']],
#  ['Sugar Rush (Offensive Line #2)', 24.42, ['star-rating', 'One']],
#  ['Saga, Volume 2 (Saga (Collected Editions) #2)',
#   11.75,
#   ['star-rating', 'Three']],
#  ['Run, Spot, Run: The Ethics of Keeping Pets', 20.02, ['star-rating', 'One']],
#  ['New Moon (Twilight #2)', 12.86, ['star-rating', 'Four']],
#  ['Life', 31.58, ['star-rating', 'Five']],
#  ["Kindle Paperwhite User's Guide", 34.0, ['star-rating', 'Three']],
#  ['H is for Hawk', 57.42, ['star-rating', 'Five']],
#  ['Girl Online On Tour (Girl Online #2)', 53.47, ['star-rating', 'One']],
#  ['Fruits Basket, Vol. 2 (Fruits Basket #2)', 11.64, ['star-rating', 'Five']],
#  ['Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An Unofficial Minecraft Book)',
#   52.88,
#   ['star-rating', 'Four']],
#  ['Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)',
#   18.51,
#   ['star-rating', 'Four']],
#  ['While You Were Mine', 41.32, ['star-rating', 'Five']],
#  ['Where Lightning Strikes (Bleeding Stars #3)',
#   39.77,
#   ['star-rating', 'Three']],
#  ["When I'm Gone", 51.96, ['star-rating', 'Three']],
#  ['Ways of Seeing', 39.51, ['star-rating', 'Five']],
#  ['Vampire Knight, Vol. 1 (Vampire Knight #1)', 15.4, ['star-rating', 'One']],
#  ['Vampire Girl (Vampire Girl #1)', 53.82, ['star-rating', 'Two']],
#  ['Twenty Love Poems and a Song of Despair', 30.95, ['star-rating', 'Four']],
#  ['Travels with Charley: In Search of America',
#   57.82,
#   ['star-rating', 'Five']],
#  ['Three Wishes (River of Time: California #1)',
#   44.18,
#   ['star-rating', 'Two']],
#  ['This One Moment (Pushing Limits #1)', 48.71, ['star-rating', 'One']],
#  ['The Zombie Room', 19.69, ['star-rating', 'Five']],
#  ['The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The Divine)',
#   36.52,
#   ['star-rating', 'Two']],
#  ['The Tumor', 41.56, ['star-rating', 'Five']],
#  ['The Story of Hong Gildong', 43.19, ['star-rating', 'Four']],
#  ['The Silent Wife', 12.34, ['star-rating', 'Five']],
#  ['The Silent Twin (Detective Jennifer Knight #3)',
#   36.25,
#   ['star-rating', 'Three']],
#  ['The Selfish Gene', 29.45, ['star-rating', 'One']],
#  ['The Secret Healer', 34.56, ['star-rating', 'Three']],
#  ['The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) #1)',
#   54.12,
#   ['star-rating', 'Three']],
#  ['The Republic', 33.78, ['star-rating', 'Three']],
#  ['The Odyssey', 29.64, ['star-rating', 'Three']],
#  ["The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)",
#   57.7,
#   ['star-rating', 'Four']],
#  ['The Nicomachean Ethics', 36.34, ['star-rating', 'One']],
#  ['The Name of the Wind (The Kingkiller Chronicle #1)',
#   50.59,
#   ['star-rating', 'Three']],
#  ['The Mirror & the Maze (The Wrath and the Dawn #1.5)',
#   29.38,
#   ['star-rating', 'One']],
#  ['The Little Prince', 45.42, ['star-rating', 'Two']],
#  ['The Light of the Fireflies', 54.43, ['star-rating', 'One']],
#  ['The Last Girl (The Dominion Trilogy #1)', 36.26, ['star-rating', 'Two']],
#  ['The Iliad', 16.16, ['star-rating', 'One']],
#  ['The Hook Up (Game On #1)', 36.29, ['star-rating', 'Five']],
#  ['The Haters', 27.89, ['star-rating', 'Five']],
#  ['The Girl You Lost', 12.29, ['star-rating', 'Five']],
#  ['The Girl In The Ice (DCI Erika Foster #1)',
#   15.85,
#   ['star-rating', 'Three']],
#  ['The End of the Jesus Era (An Investigation #1)',
#   14.4,
#   ['star-rating', 'One']],
#  ['The Edge of Reason (Bridget Jones #2)', 19.18, ['star-rating', 'Four']],
#  ['The Complete Maus (Maus #1-2)', 10.64, ['star-rating', 'Three']],
#  ['The Communist Manifesto', 14.76, ['star-rating', 'Three']],
#  ['The Bhagavad Gita', 57.49, ['star-rating', 'Three']],
#  ['The Bette Davis Club', 30.66, ['star-rating', 'Three']],
#  ['The Art of Not Breathing', 40.83, ['star-rating', 'Four']],
#  ['Taking Shots (Assassins #1)', 18.88, ['star-rating', 'Two']],
#  ['Starlark', 25.83, ['star-rating', 'Three']],
#  ['Skip Beat!, Vol. 01 (Skip Beat! #1)', 42.12, ['star-rating', 'Three']],
#  ['Sister Sable (The Mad Queen #1)', 13.33, ['star-rating', 'Three']],
#  ['Shatter Me (Shatter Me #1)', 42.4, ['star-rating', 'One']],
#  ['Shameless', 58.35, ['star-rating', 'Three']],
#  ['Shadow Rites (Jane Yellowrock #10)', 21.72, ['star-rating', 'Four']],
#  ['Settling the Score (The Summer Games #1)', 44.91, ['star-rating', 'Two']],
#  ['Sense and Sensibility', 37.46, ['star-rating', 'One']],
#  ['Saga, Volume 1 (Saga (Collected Editions) #1)',
#   28.48,
#   ['star-rating', 'One']],
#  ['Rhythm, Chord & Malykhin', 28.34, ['star-rating', 'Two']],
#  ['Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)',
#   46.96,
#   ['star-rating', 'Five']],
#  ['Paradise Lost (Paradise #1)', 24.96, ['star-rating', 'One']],
#  ['Paper Girls, Vol. 1 (Paper Girls #1-5)', 21.71, ['star-rating', 'Four']],
#  ['Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1)',
#   29.87,
#   ['star-rating', 'Three']],
#  ['Origins (Alphas 0.5)', 28.99, ['star-rating', 'One']],
#  ['One Second (Seven #7)', 52.94, ['star-rating', 'Two']],
#  ['On the Road (Duluoz Legend)', 32.36, ['star-rating', 'Three']],
#  ["Old Records Never Die: One Man's Quest for His Vinyl and His Past",
#   55.66,
#   ['star-rating', 'Two']],
#  ['Off Sides (Off #1)', 39.45, ['star-rating', 'Five']],
#  ['Of Mice and Men', 47.11, ['star-rating', 'Two']],
#  ['Myriad (Prentor #1)', 58.75, ['star-rating', 'Four']],
#  ['My Perfect Mistake (Over the Top #1)', 38.92, ['star-rating', 'Two']],
#  ['Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)',
#   39.39,
#   ['star-rating', 'Four']],
#  ['Meditations', 25.89, ['star-rating', 'Two']],
#  ['Matilda', 28.34, ['star-rating', 'One']],
#  ['Lost Among the Living', 27.7, ['star-rating', 'Four']],
#  ['Lord of the Flies', 24.89, ['star-rating', 'Three']],
#  ['Listen to Me (Fusion #1)', 58.99, ['star-rating', 'Three']],
#  ['Kitchens of the Great Midwest', 57.2, ['star-rating', 'Five']],
#  ['Jane Eyre', 38.43, ['star-rating', 'Five']],
#  ['Imperfect Harmony', 34.74, ['star-rating', 'Four']],
#  ['Icing (Aces Hockey #2)', 40.44, ['star-rating', 'Four']],
#  ['Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)',
#   45.24,
#   ['star-rating', 'Three']],
#  ["Having the Barbarian's Baby (Ice Planet Barbarians #7.5)",
#   34.96,
#   ['star-rating', 'Four']],
#  ['Giant Days, Vol. 1 (Giant Days #1-4)', 56.76, ['star-rating', 'Four']],
#  ['Fruits Basket, Vol. 1 (Fruits Basket #1)', 40.28, ['star-rating', 'Five']],
#  ['Frankenstein', 38.0, ['star-rating', 'Two']],
#  ['Forever Rockers (The Rocker #12)', 28.8, ['star-rating', 'Three']],
#  ['Fighting Fate (Fighting #6)', 39.24, ['star-rating', 'Three']],
#  ['Emma', 32.93, ['star-rating', 'Two']],
#  ['Eat, Pray, Love', 51.32, ['star-rating', 'Three']],
#  ['Deep Under (Walker Security #1)', 47.09, ['star-rating', 'Five']],
#  ["Choosing Our Religion: The Spiritual Lives of America's Nones",
#   28.42,
#   ['star-rating', 'Four']],
#  ['Charlie and the Chocolate Factory (Charlie Bucket #1)',
#   22.85,
#   ['star-rating', 'Three']],
#  ["Charity's Cross (Charles Towne Belles #4)", 41.24, ['star-rating', 'One']],
#  ['Bright Lines', 39.07, ['star-rating', 'Five']],
#  ["Bridget Jones's Diary (Bridget Jones #1)", 29.82, ['star-rating', 'One']],
#  ['Bounty (Colorado Mountain #7)', 37.26, ['star-rating', 'Four']],
#  ['Blood Defense (Samantha Brinkman #1)', 20.3, ['star-rating', 'Three']],
#  ['Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)',
#   34.65,
#   ['star-rating', 'Five']],
#  ['Beyond Good and Evil', 43.38, ['star-rating', 'One']],
#  ["Alice in Wonderland (Alice's Adventures in Wonderland #1)",
#   55.53,
#   ['star-rating', 'One']],
#  ['Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)',
#   57.06,
#   ['star-rating', 'Four']],
#  ["A Spy's Devotion (The Regency Spies of London #1)",
#   16.97,
#   ['star-rating', 'Five']],
#  ["1st to Die (Women's Murder Club #1)", 53.98, ['star-rating', 'One']],
#  ['1,000 Places to See Before You Die', 26.08, ['star-rating', 'Five']]]

# %%
ipynb-py-convert Books_scraping.ipynb book_scraping.py
# Out:
#   Cell In[32], line 1
#     ipynb-py-convert Books_scraping.ipynb book_scraping.py
#                      ^
# SyntaxError: invalid syntax

# %%
pip install ipynb-py-convert
# Out:
# Collecting ipynb-py-convert
#   Using cached ipynb_py_convert-0.4.6-py3-none-any.whl
# Installing collected packages: ipynb-py-convert
# Successfully installed ipynb-py-convert-0.4.6
# Note: you may need to restart the kernel to use updated packages.
